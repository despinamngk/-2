# %%
# !pip install Twython
import pandas as pd
import numpy as np 
from twython import Twython

CONSUMER_KEY = "zJqvZslXaZsCXGE8pjXxghI0Z"
CONSUMER_SECRET = "08W0dMtVqNRtJ3J7S9SGyvhrnoCC2dmpDFgOZscdgDmFt81Gsm"
OAUTH_TOKEN = "1530236331921653760-Vh7uPCVtmpydrbcAG2EO9i4GCmKq0a"
OAUTH_TOKEN_SECRET = "LWnoFmdsPcPDTXDM8o6gNRklQ98RFPM5lGquwcFLrW47C"
twitter = Twython(
    CONSUMER_KEY, CONSUMER_SECRET,
    OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Στις 19/6 τράβηξα 10.000 tweets με τα key words "Ουκρανία" και "πόλεμος". Η αναζήτηση έφτασε μέχρι τις 10/6. Γι' αυτό στις 22/6 τράβηξα 3.000 ακόμα tweets με το ίδιο θέμα, ώστε τα δεδομένα μου να καλύπτουν τουλάχιστον ένα 10ήμερο, και στη συνέχεια έκανα merge τα dataframes.
# **Ο κώδικας με τη λίστα "tweets" εξαιτίας του μεγάλου αριθμού tweets (10.000) κάποιες φορές δεν τρέχει. Το "tweets2", παρακάτω, τρέχει κανονικά.*

# %%
tweets = []
MAX_ATTEMPTS = 100
COUNT_OF_TWEETS_TO_BE_FETCHED = 10000 

for i in range(0,MAX_ATTEMPTS):
  if(COUNT_OF_TWEETS_TO_BE_FETCHED < len(tweets)):
    print("We Got ", len(tweets), " tweets!!!")
    break 
  if(0 == i):
    results = twitter.search(q=("ουκρανία-filter:retweets"or"ουκρανια-filter:retweets"or"πόλεμος-filter:retweets" or "πολεμος-filter:retweets") , lang= 'el' , count='100')
    
    print("I Got:", len(results['statuses']), " tweets")
  else:
    results = twitter.search(q=("ουκρανία-filter:retweets"or"ουκρανια-filter:retweets"or"πόλεμος-filter:retweets" or "πολεμος-filter:retweets") , lang= 'el' , count='100', include_entities='true',max_id=next_max_id)
    
    print("I Got:", len(results['statuses']), " tweets")

  for result in results['statuses']:
    tweets.append(result)

  try:
    next_results_url_params = results['search_metadata']['next_results']
    next_max_id = next_results_url_params.split('max_id=')[1].split('&')[0]
  except:
    break
# Out:
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# ...

# %%
len(tweets)
# Out:
# 10000

# %%
tweets_df = pd.DataFrame(tweets)
tweets_df.tail(2)
# Out:
#                           created_at                   id  \
# 9998  Fri Jun 10 18:51:19 +0000 2022  1535333805711663104
# 9999  Fri Jun 10 18:50:50 +0000 2022  1535333686064947201
#
#                    id_str                                               text  \
# 9998  1535333805711663104  Εάν πραγματικά θέλεις να καταλάβεις τι και για...
# 9999  1535333686064947201  Τεράστια ανταπόκριση στο κάλεσμα ανθρωπιστικής...
#
#       truncated                                           entities  \
# 9998       True  {'hashtags': [{'text': 'Ουκρανια', 'indices': ...
# 9999       True  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                                metadata  \
# 9998  {'iso_language_code': 'el', 'result_type': 're...
# 9999  {'iso_language_code': 'el', 'result_type': 're...
#
#                                                  source  \
# 9998  <a href="https://mobile.twitter.com" rel="nofo...
# 9999  <a href="https://mobile.twitter.com" rel="nofo...
#
# ...

# %%
#tweets2_df = pd.DataFrame(tweets2)

# %%
#tweets2_df.tail(2)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
tweets_df.to_csv("/content/gdrive/My Drive/Colab Notebooks/tweets_ukraine.tsv", sep='\t')

# %%
ukrainetweets = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/tweets_ukraine.tsv", sep='\t')
ukrainetweets.head(1)
# Out:
#    Unnamed: 0                      created_at                   id  \
# 0           0  Sun Jun 19 12:17:02 +0000 2022  1538496073328730112
#
#                 id_str                                               text  \
# 0  1538496073328730112  Ρωσία: H επίθεση στην ανατολική Ουκρανία εξελί...
#
#    truncated                                           entities  \
# 0      False  {'hashtags': [{'text': 'Επικαιρότητα', 'indice...
#
#                                             metadata  \
# 0  {'iso_language_code': 'el', 'result_type': 're...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://www.wpautopublish.com" rel="no...                    NaN
#
#    ...  retweet_count  favorite_count  favorited retweeted possibly_sensitive  \
# 0  ...              0               0      False     False              False
#
#    lang  extended_entities quoted_status_id  quoted_status_id_str  \
# ...

# %%
tweets2 = []
MAX_ATTEMPTS = 100
COUNT_OF_TWEETS_TO_BE_FETCHED = 3000 

for i in range(0,MAX_ATTEMPTS):
  if(COUNT_OF_TWEETS_TO_BE_FETCHED < len(tweets2)):
    print("We Got ", len(tweets2), " tweets!!!")
    break 
  if(0 == i):
    results = twitter.search(q=("ουκρανία-filter:retweets"or"ουκρανια-filter:retweets"or"πόλεμος-filter:retweets" or "πολεμος-filter:retweets") , lang= 'el' , count='100')
    
    print("I Got:", len(results['statuses']), " tweets")
  else:
    results = twitter.search(q=("ουκρανία-filter:retweets"or"ουκρανια-filter:retweets"or"πόλεμος-filter:retweets" or "πολεμος-filter:retweets") , lang= 'el' , count='100', include_entities='true',max_id=next_max_id)
    
    print("I Got:", len(results['statuses']), " tweets")

  for result in results['statuses']:
    tweets2.append(result)

  try:
    next_results_url_params = results['search_metadata']['next_results']
    next_max_id = next_results_url_params.split('max_id=')[1].split('&')[0]
  except:
    break
# Out:
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# We Got  3100  tweets!!!

# %%
len(tweets2)
# Out:
# 3100

# %%
tweets2_df = pd.DataFrame(tweets2)
tweets2_df.head(2)
# Out:
#                        created_at                   id               id_str  \
# 0  Wed Jun 22 09:41:43 +0000 2022  1539544151653552128  1539544151653552128
# 1  Wed Jun 22 09:39:56 +0000 2022  1539543700287758337  1539543700287758337
#
#                                                 text  truncated  \
# 0  Ουκρανία: Εκτεταμένοι ρωσικοί βομβαρδισμοί, αλ...      False
# 1  Θα αποσύρει τους τενεκέδες τους από την Ουκραν...       True
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'Ουκρανία', 'indices': ...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'el', 'result_type': 're...
# 1  {'iso_language_code': 'el', 'result_type': 're...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="https://www.hootsuite.com" rel="nofol...                    NaN
# ...

# %%
tweets2_df.to_csv("/content/gdrive/My Drive/Colab Notebooks/tweets2_ukraine.tsv", sep='\t')

# %%
ukrainetweets2 = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/tweets2_ukraine.tsv", sep='\t')
ukrainetweets2.tail(1)
# Out:
#       Unnamed: 0                      created_at                   id  \
# 3099        3099  Sun Jun 19 08:16:02 +0000 2022  1538435423688699904
#
#                    id_str                                               text  \
# 3099  1538435423688699904  Ουκρανία: Ρωσικό πλήγμα σε αποθήκη καυσίμων   ...
#
#       truncated                                           entities  \
# 3099      False  {'hashtags': [{'text': 'Επικαιρότητα', 'indice...
#
#                                                metadata  \
# 3099  {'iso_language_code': 'el', 'result_type': 're...
#
#                                                  source  \
# 3099  <a href="http://www.wpautopublish.com" rel="no...
#
#       in_reply_to_status_id  ...  retweet_count  favorite_count  favorited  \
# 3099                    NaN  ...              0               0      False
#
#      retweeted possibly_sensitive  lang  quoted_status_id  \
# 3099     False              False    el               NaN
#
# ...

# %%
df_ukrainetweets=pd.concat([ukrainetweets, ukrainetweets2], axis="rows")
df_ukrainetweets.head(2)
# Out:
#    Unnamed: 0                      created_at                   id  \
# 0           0  Sun Jun 19 12:17:02 +0000 2022  1538496073328730112
# 1           1  Sun Jun 19 12:16:15 +0000 2022  1538495877987409921
#
#                 id_str                                               text  \
# 0  1538496073328730112  Ρωσία: H επίθεση στην ανατολική Ουκρανία εξελί...
# 1  1538495877987409921  Ρωσία: Το υπουργείο Άμυνας δηλώνει ότι η επίθε...
#
#    truncated                                           entities  \
# 0      False  {'hashtags': [{'text': 'Επικαιρότητα', 'indice...
# 1      False  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'el', 'result_type': 're...
# 1  {'iso_language_code': 'el', 'result_type': 're...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://www.wpautopublish.com" rel="no...                    NaN
# ...

# %%
df_ukrainetweets.tail(2)
# Out:
#       Unnamed: 0                      created_at                   id  \
# 3098        3098  Sun Jun 19 08:16:28 +0000 2022  1538435531104784384
# 3099        3099  Sun Jun 19 08:16:02 +0000 2022  1538435423688699904
#
#                    id_str                                               text  \
# 3098  1538435531104784384  Arno Klarsfeld, ο δικηγόρος του Συνδέσμου Γιων...
# 3099  1538435423688699904  Ουκρανία: Ρωσικό πλήγμα σε αποθήκη καυσίμων   ...
#
#       truncated                                           entities  \
# 3098       True  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3099      False  {'hashtags': [{'text': 'Επικαιρότητα', 'indice...
#
#                                                metadata  \
# 3098  {'iso_language_code': 'el', 'result_type': 're...
# 3099  {'iso_language_code': 'el', 'result_type': 're...
#
#                                                  source  \
# 3098  <a href="https://mobile.twitter.com" rel="nofo...
# ...

# %%
df_ukrainetweets.to_csv("/content/gdrive/My Drive/Colab Notebooks/twitter_ukraine.tsv", sep='\t')
